# %% [markdown]
# <a href="https://colab.research.google.com/github/tran0467/User-behaviour-analysis/blob/main/Data_analysis_(Categorial).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from scipy.stats import kendalltau, pearsonr, spearmanr
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
from sklearn.linear_model import LinearRegression
# %matplotlib inline     
sns.set(color_codes=True)
# %load_ext google.colab.data_table

def kendall_pval(x,y):
  return kendalltau(x,y)[1]
    
def pearsonr_pval(x,y):
  return pearsonr(x,y)[1]
    
def spearmanr_pval(x,y):
  return spearmanr(x,y)[1]

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Enable multiple cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
# First-Second value features against First Value Health Profile
pathGeneral = "/content/drive/MyDrive/05. STUDY/FLINDERS/2020-08 Masters Thesis/General_Feature_with_Spent_Time.csv"
dfGeneral = pd.read_csv(pathGeneral)
pathDiffFirstSecond = "/content/drive/MyDrive/05. STUDY/FLINDERS/2020-08 Masters Thesis/Diff_Direction_first_second_value.csv"
dfDiffFirstSecond = pd.read_csv(pathDiffFirstSecond)
pathDiffFirstLast = "/content/drive/MyDrive/05. STUDY/FLINDERS/2020-08 Masters Thesis/Diff_Direction_first_last_value.csv"
dfDiffFirstLast = pd.read_csv(pathDiffFirstLast)

pathProfileFirst = "/content/drive/MyDrive/05. STUDY/FLINDERS/2020-08 Masters Thesis/dfHealthProfile_FirstValue.csv"
dfProfileFirst = pd.read_csv(pathProfileFirst)
pathProfileLast = "/content/drive/MyDrive/05. STUDY/FLINDERS/2020-08 Masters Thesis/dfHealthProfile_LastValue.csv"
dfProfileLast = pd.read_csv(pathProfileLast)

# %%
dfDiffFirstSecond2 = dfDiffFirstSecond[['Visitor_ID','Age Direction',	'Height Direction',	'Weight Direction',
                                        'Smoking Direction',	'Alcohol Direction',	'Conceive Direction', 'Month Direction',
                                        'Children Direction',	'STI Direction',	'STI Positive Direction',	
                                        'Menstrual_Information Direction', 'Sex_Frequency Direction', 'Sex_Right_Time Direction',
                                        'Contraception Direction']].copy()
dfDiffFirstSecond2 = dfDiffFirstSecond2.replace([1,0.5],"Positive")
dfDiffFirstSecond2 = dfDiffFirstSecond2.replace([-1,-0.5],"Negative")
dfDiffFirstSecond2 = dfDiffFirstSecond2.replace(0,"No change")

dfDiffFirstLast2 = dfDiffFirstLast[['Visitor_ID','Age Direction',	'Height Direction',	'Weight Direction',
                                        'Smoking Direction',	'Alcohol Direction',	'Conceive Direction', 'Month Direction',
                                        'Children Direction',	'STI Direction',	'STI Positive Direction',	
                                        'Menstrual_Information Direction', 'Sex_Frequency Direction', 'Sex_Right_Time Direction',
                                        'Contraception Direction']].copy()
dfDiffFirstLast2 = dfDiffFirstLast2.replace([1,0.5],"Positive")
dfDiffFirstLast2 = dfDiffFirstLast2.replace([-1,-0.5],"Negative")
dfDiffFirstLast2 = dfDiffFirstLast2.replace(0,"No change")

dfProfileFirst2 = dfProfileFirst[['Visitor_ID','Gender','Trying_Conceive', 'Previous_Children','STI_Tested','STI_Positive','Menstrual_Information',
                                  'Sex_Right_Time','Contraception']].copy()
dfProfileLast2 = dfProfileLast[['Visitor_ID','Gender','Trying_Conceive', 'Previous_Children','STI_Tested','STI_Positive','Menstrual_Information',
                                  'Sex_Right_Time','Contraception']].copy()

dfProfileFirst_DiffSecond = dfProfileFirst2.merge(dfDiffFirstSecond2, on = 'Visitor_ID', how = 'left')
dfProfileFirst_DiffLast = dfProfileFirst2.merge(dfDiffFirstLast2, on = 'Visitor_ID', how = 'left')
dfProfileLast_DiffSecond = dfProfileLast2.merge(dfDiffFirstSecond2, on = 'Visitor_ID', how = 'left')
dfProfileLast_DiffLast = dfProfileLast2.merge(dfDiffFirstLast2, on = 'Visitor_ID', how = 'left')
dfProfileLast_DiffLast
# Out:
#             Visitor_ID Gender  ... Sex_Right_Time Direction Contraception Direction
# 0     00052d764372f8e1    Men  ...                      NaN                     NaN
# 1     0010038311a193ca  Women  ...                      NaN               No change
# 2     001ad62ea7bffe81  Women  ...                      NaN                     NaN
# 3     001f49b0bfe37865  Women  ...                No change               No change
# 4     00274a3448b59cbd  Women  ...                No change               No change
# ...                ...    ...  ...                      ...                     ...
# 4125  ffbbfa8e0095fa45  Women  ...                No change               No change
# 4126  ffc980a4b6d372c6  Women  ...                No change               No change
# 4127  ffcf6cfd8c6aac98  Women  ...                      NaN                     NaN
# 4128  ffd1a676c10e1bcf  Women  ...                 Negative                Negative
# ...

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)

# %%
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)

# %%
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
# Out:
# (264.7605913871355,
#  3.220831963968855e-58,
#  2,
#  array([[  27.7559322 ,  294.2440678 ],
#         [ 129.81501211, 1376.18498789],
#         [ 198.42905569, 2103.57094431]]))
# (37.07090586906388,
#  8.91569228642892e-09,
#  2,
#  array([[ 107.66198547, 1141.33801453],
#         [  62.062954  ,  657.937046  ],
#         [ 186.27506053, 1974.72493947]]))
# (26.308096898640933,
#  1.9376232800688753e-06,
#  2,
#  array([[ 185.8440678 , 1970.1559322 ],
#         [  38.01355932,  402.98644068],
#         [ 132.14237288, 1400.85762712]]))
# (9.348217728651253,
#  0.00933383914976699,
#  2,
#  array([[  33.35883777,  353.64116223],
#         [ 312.12493947, 3308.87506053],
#         [  10.51622276,  111.48377724]]))
# (19.437915845290632,
#  6.0132630761131436e-05,
#  2,
#  array([[  54.56368039,  578.43631961],
#         [ 271.00823245, 2872.99176755],
#         [  30.42808717,  322.57191283]]))
# (0.9201907559133595,
#  0.6312234378340202,
#  2,
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Gender']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Contraception']) 
stats.chi2_contingency(contigency)
# Out:
# (700.0613954891362,
#  9.629405440110647e-153,
#  2,
#  array([[  70.46368039,  364.53631961],
#         [ 243.95012107, 1262.04987893],
#         [ 354.58619855, 1834.41380145]]))
# (62.89475367374173,
#  2.2007857705921392e-14,
#  2,
#  array([[ 210.25714286, 1087.74285714],
#         [ 116.62953995,  603.37046005],
#         [ 342.11331719, 1769.88668281]]))
# (33.701951862167014,
#  4.805229542478556e-08,
#  2,
#  array([[ 326.56271186, 1689.43728814],
#         [  71.43559322,  369.56440678],
#         [ 271.00169492, 1401.99830508]]))
# (14.444801907361176,
#  0.0007300475027486001,
#  2,
#  array([[  62.8503632 ,  325.1496368 ],
#         [ 586.54939467, 3034.45060533],
#         [  19.60024213,  101.39975787]]))
# (134.18153022226815,
#  7.292071621434175e-30,
#  2,
#  array([[ 111.93196126,  579.06803874],
#         [ 509.28232446, 2634.71767554],
#         [  47.78571429,  247.21428571]]))
# (1.1451436124257859,
#  0.564072885506026,
#  2,
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Gender']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Previous_Children']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['STI_Tested']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['STI_Positive']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
stats.chi2_contingency(contigency)
##
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Contraception']) 
stats.chi2_contingency(contigency)
# Out:
# (518.8603210711149,
#  2.1424605811048715e-113,
#  2,
#  array([[  52.15932203,  269.84067797],
#         [ 243.95012107, 1262.04987893],
#         [ 372.8905569 , 1929.1094431 ]]))
# (183.53925029570087,
#  1.3962339439295801e-40,
#  2,
#  array([[ 202.31985472, 1046.68014528],
#         [ 116.62953995,  603.37046005],
#         [ 350.05060533, 1810.94939467]]))
# (188.0944611187029,
#  1.4315506872323344e-41,
#  2,
#  array([[ 349.24067797, 1806.75932203],
#         [  71.43559322,  369.56440678],
#         [ 248.32372881, 1284.67627119]]))
# (14.415541064978106,
#  0.000740806920692048,
#  2,
#  array([[  62.68837772,  324.31162228],
#         [ 586.54939467, 3034.45060533],
#         [  19.7622276 ,  102.2377724 ]]))
# (151.71047514376318,
#  1.138908670050192e-33,
#  2,
#  array([[ 102.53680387,  530.46319613],
#         [ 509.28232446, 2634.71767554],
#         [  57.18087167,  295.81912833]]))
# (1.1451436124257859,
#  0.564072885506026,
#  2,
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender         Men  Women
# Age Direction
# Negative       143    179
# No change       11   1495
# Positive       515   1787
# (518.8603210711149,
#  2.1424605811048715e-113,
#  2,
#  array([[  52.15932203,  269.84067797],
#         [ 243.95012107, 1262.04987893],
#         [ 372.8905569 , 1929.1094431 ]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          0         1
# 2         0          0         1
# 3         0          0         1
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         526   3282
# 1         143    179
#
# Chi2 value= 202.5052641992739
# p-value= 5.931216108378838e-46
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          658   1966
# 1           11   1495
#
# Chi2 value= 415.9998641078357
# p-value= 1.811894735455998e-92
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         154   1674
# 1         515   1787
#
# Chi2 value= 144.98576250604805
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender            Men  Women
# Weight Direction
# Negative          237   1919
# No change          29    412
# Positive          403   1130
# (188.0944611187029,
#  1.4315506872323344e-41,
#  2,
#  array([[ 349.24067797, 1806.75932203],
#         [  71.43559322,  369.56440678],
#         [ 248.32372881, 1284.67627119]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          0         1
# 4         0          0         1
# Gender    Men  Women
# Negative
# 0         432   1542
# 1         237   1919
#
# Chi2 value= 89.25840811661553
# p-value= 3.464672161504457e-21
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          640   3049
# 1           29    412
#
# Chi2 value= 32.888250755794374
# p-value= 9.761142401353487e-09
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         266   2331
# 1         403   1130
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender             Men  Women
# Smoking Direction
# Negative            85    302
# No change          557   3064
# Positive            27     95
# (14.415541064978106,
#  0.000740806920692048,
#  2,
#  array([[  62.68837772,  324.31162228],
#         [ 586.54939467, 3034.45060533],
#         [  19.7622276 ,  102.2377724 ]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         1          0         0
# 2         0          1         0
# 3         0          1         0
# 4         0          0         1
# Gender    Men  Women
# Negative
# 0         584   3159
# 1          85    302
#
# Chi2 value= 9.992348723502515
# p-value= 0.001571919827848069
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          112    397
# 1          557   3064
#
# Chi2 value= 13.929973969415474
# p-value= 0.00018974835053964186
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         642   3366
# 1          27     95
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender             Men  Women
# Alcohol Direction
# Negative           149    484
# No change          395   2749
# Positive           125    228
# (151.71047514376318,
#  1.138908670050192e-33,
#  2,
#  array([[ 102.53680387,  530.46319613],
#         [ 509.28232446, 2634.71767554],
#         [  57.18087167,  295.81912833]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         520   2977
# 1         149    484
#
# Chi2 value= 29.036451209430066
# p-value= 7.102913267703498e-08
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          274    712
# 1          395   2749
#
# Chi2 value= 127.06109362351013
# p-value= 1.801418564807427e-29
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         544   3233
# 1         125    228
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender           Men  Women
# Month Direction
# Negative         135    257
# No change        417   2612
# Positive          42    142
# (113.45088981535095,
#  2.314473928893194e-25,
#  2,
#  array([[  64.59029126,  327.40970874],
#         [ 499.09181692, 2529.90818308],
#         [  30.31789182,  153.68210818]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         534   3204
# 1         135    257
#
# Chi2 value= 104.67296011294484
# p-value= 1.4405355351936046e-24
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          252    849
# 1          417   2612
#
# Chi2 value= 48.82159279088129
# p-value= 2.8033644431086893e-12
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         627   3319
# 1          42    142
#
# Chi2 value= 5.730911590926353
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender              Men  Women
# Children Direction
# Negative             22     37
# No change           524   2858
# Positive             30     30
# (70.02078111350683,
#  6.239942272591712e-16,
#  2,
#  array([[   9.70694087,   49.29305913],
#         [ 556.42159383, 2825.57840617],
#         [   9.8714653 ,   50.1285347 ]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         647   3424
# 1          22     37
#
# Chi2 value= 18.06698977357248
# p-value= 2.1326700424670716e-05
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          145    603
# 1          524   2858
#
# Chi2 value= 6.548742140059076
# p-value= 0.01049583351856138
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         639   3431
# 1          30     30
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender         Men  Women
# STI Direction
# Negative        50     65
# No change      437   2465
# Positive        91    425
# (66.01061034500724,
#  4.634235396481741e-15,
#  2,
#  array([[  18.81403906,   96.18596094],
#         [ 474.76818568, 2427.23181432],
#         [  84.41777526,  431.58222474]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         619   3396
# 1          50     65
#
# Chi2 value= 62.79995234326319
# p-value= 2.2880437640558634e-15
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          232    996
# 1          437   2465
#
# Chi2 value= 9.06312315484615
# p-value= 0.0026081610724401883
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         578   3036
# 1          91    425
#
# Chi2 value= 0.7802455549918559
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender                  Men  Women
# STI Positive Direction
# Negative                 25     70
# No change               385   2057
# Positive                  5     41
# (8.485416671587302,
#  0.014368624039191754,
#  2,
#  array([[  15.26325978,   79.73674022],
#         [ 392.34610918, 2049.65389082],
#         [   7.39063105,   38.60936895]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          0         0
# 2         0          0         0
# 3         0          0         0
# 4         0          0         0
# Gender    Men  Women
# Negative
# 0         644   3391
# 1          25     70
#
# Chi2 value= 6.589062497819278
# p-value= 0.010260719171468655
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          284   1404
# 1          385   2057
#
# Chi2 value= 0.7482312957625278
# p-value= 0.3870367913839273
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         664   3420
# 1           5     41
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender                   Men  Women
# Sex_Frequency Direction
# Negative                 223    402
# No change                252   2083
# Positive                 119    526
# (224.1213922470481,
#  2.151087295586203e-49,
#  2,
#  array([[ 102.98196949,  522.01803051],
#         [ 384.740638  , 1950.259362  ],
#         [ 106.27739251,  538.72260749]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         446   3059
# 1         223    402
#
# Chi2 value= 204.21278838293676
# p-value= 2.5150914473232797e-46
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          417   1378
# 1          252   2083
#
# Chi2 value= 114.76009937802111
# p-value= 8.881787650947665e-27
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         550   2935
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender                    Men  Women
# Sex_Right_Time Direction
# Negative                   37    122
# No change                 475   2523
# Positive                   67    255
# (10.439418835967194,
#  0.005408900627355771,
#  2,
#  array([[  26.46191434,  132.53808566],
#         [ 498.94854843, 2499.05145157],
#         [  53.58953722,  268.41046278]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          0         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         632   3339
# 1          37    122
#
# Chi2 value= 5.5626595568866035
# p-value= 0.01834752078194738
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          194    938
# 1          475   2523
#
# Chi2 value= 0.9203922163090105
# p-value= 0.33737201014610946
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         602   3206
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Gender                   Men  Women
# Contraception Direction
# Negative                  31    100
# No change                526   2781
# Positive                  23     53
# (16.17275735040317,
#  0.00030770203096045753,
#  2,
#  array([[  21.6220831 ,  109.3779169 ],
#         [ 545.83380763, 2761.16619237],
#         [  12.54410928,   63.45589072]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         638   3361
# 1          31    100
#
# Chi2 value= 5.001342829118309
# p-value= 0.02532766088850768
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          143    680
# 1          526   2781
#
# Chi2 value= 0.9432724904077412
# p-value= 0.33143765947446907
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0         646   3408
# 1          23     53
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive   No   Yes
# Age Direction
# Negative          98   187
# No change        406   857
# Positive         521  1389
# (11.992014385771508,
#  0.0024886691410797327,
#  2,
#  array([[  84.47802198,  200.52197802],
#         [ 374.37102371,  888.62897629],
#         [ 566.15095431, 1343.84904569]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          0         1
# 2         0          0         1
# 3         0          0         1
# 4         0          1         0
# Trying_Conceive   No   Yes
# Negative
# 0                927  2246
# 1                 98   187
#
# Chi2 value= 3.1091951131270323
# p-value= 0.07785142425415184
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# No change
# 0                619  1576
# 1                406   857
#
# Chi2 value= 5.795631905893097
# p-value= 0.01606603940637824
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# Positive
# 0                504  1044
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive    No   Yes
# Weight Direction
# Negative          586  1207
# No change          88   240
# Positive          351   986
# (16.55692496741045,
#  0.00025392731744019754,
#  2,
#  array([[ 531.47050318, 1261.52949682],
#         [  97.2238288 ,  230.7761712 ],
#         [ 396.30566802,  940.69433198]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          0         1
# 4         0          0         1
# Trying_Conceive   No   Yes
# Negative
# 0                439  1226
# 1                586  1207
#
# Chi2 value= 16.21348264265223
# p-value= 5.658992302649072e-05
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# No change
# 0                937  2193
# 1                 88   240
#
# Chi2 value= 1.2291505503523186
# p-value= 0.267572299415764
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# Positive
# 0                674  1447
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive     No   Yes
# Alcohol Direction
# Negative           176   361
# No change          747  1874
# Positive           102   198
# (6.896270943949977,
#  0.03180488222237137,
#  2,
#  array([[ 159.17437825,  377.82562175],
#         [ 776.90138809, 1844.09861191],
#         [  88.92423366,  211.07576634]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Trying_Conceive   No   Yes
# Negative
# 0                849  2072
# 1                176   361
#
# Chi2 value= 2.8173617219822287
# p-value= 0.09324956114181593
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# No change
# 0                278   559
# 1                747  1874
#
# Chi2 value= 6.533594587246597
# p-value= 0.010585582523617736
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# Positive
# 0                923  2235
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive      No   Yes
# Conceive Direction
# Negative            129    19
# No change           870  2376
# Positive             26    38
# (251.04685825062998,
#  3.0610285574089815e-55,
#  2,
#  array([[  43.86928861,  104.13071139],
#         [ 962.16020821, 2283.83979179],
#         [  18.97050318,   45.02949682]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         1          0         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Trying_Conceive   No   Yes
# Negative
# 0                896  2414
# 1                129    19
#
# Chi2 value= 242.42380659351818
# p-value= 1.1647114015330291e-54
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# No change
# 0                155    57
# 1                870  2376
#
# Chi2 value= 202.43532300052755
# p-value= 6.143354465436727e-46
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# Positive
# 0                999  2395
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive    No   Yes
# Month Direction
# Negative            8   384
# No change        1016  1866
# Positive            1   183
# (261.4097211615027,
#  1.720284561561009e-57,
#  2,
#  array([[ 116.19433198,  275.80566802],
#         [ 854.26547137, 2027.73452863],
#         [  54.54019665,  129.45980335]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Trying_Conceive    No   Yes
# Negative
# 0                1017  2049
# 1                   8   384
#
# Chi2 value= 160.00607368854037
# p-value= 1.1280317118873021e-36
# Degrees of freedom= 1
#
# Trying_Conceive    No   Yes
# No change
# 0                   9   567
# 1                1016  1866
#
# Chi2 value= 259.6621430766406
# p-value= 2.0331108716737114e-58
# Degrees of freedom= 1
#
# Trying_Conceive    No   Yes
# Positive
# 0                1024  2250
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive      No   Yes
# Children Direction
# Negative              9    48
# No change           980  2306
# Positive             22    38
# (6.700042935007641,
#  0.03508360093542364,
#  2,
#  array([[  16.93417573,   40.06582427],
#         [ 976.24037614, 2309.75962386],
#         [  17.82544813,   42.17455187]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Trying_Conceive    No   Yes
# Negative
# 0                1016  2385
# 1                   9    48
#
# Chi2 value= 4.678157602723793
# p-value= 0.030548494894045347
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# No change
# 0                 45   127
# 1                980  2306
#
# Chi2 value= 0.8820343223926951
# p-value= 0.3476450997300107
# Degrees of freedom= 1
#
# Trying_Conceive    No   Yes
# Positive
# 0                1003  2395
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive                   No   Yes
# Menstrual_Information Direction
# Negative                          39    57
# No change                        859  2088
# Positive                          18    29
# (7.585169397479487,
#  0.022537274439359527,
#  2,
#  array([[  28.45825243,   67.54174757],
#         [ 873.60906149, 2073.39093851],
#         [  13.93268608,   33.06731392]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Trying_Conceive   No   Yes
# Negative
# 0                986  2376
# 1                 39    57
#
# Chi2 value= 5.182921906045566
# p-value= 0.022809934565453945
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# No change
# 0                166   345
# 1                859  2088
#
# Chi2 value= 2.1680593501376118
# p-value= 0.1409039496690174
# Degrees of freedom= 1
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive           No   Yes
# Sex_Frequency Direction
# Negative                 180   430
# No change                695  1525
# Positive                 150   478
# (12.932665365921297,
#  0.0015549176655367113,
#  2,
#  array([[ 180.81260844,  429.18739156],
#         [ 658.03932909, 1561.96067091],
#         [ 186.14806246,  441.85193754]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Trying_Conceive   No   Yes
# Negative
# 0                845  2003
# 1                180   430
#
# Chi2 value= 0.0009326970057559854
# p-value= 0.9756363222785029
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# No change
# 0                330   908
# 1                695  1525
#
# Chi2 value= 8.020190517062753
# p-value= 0.004625870388290719
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# Positive
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Trying_Conceive           No   Yes
# Contraception Direction
# Negative                  72    57
# No change                886  2309
# Positive                  36    39
# (60.29853103286175,
#  8.060098566078528e-14,
#  2,
#  array([[  37.72462489,   91.27537511],
#         [ 934.34245366, 2260.65754634],
#         [  21.93292145,   53.06707855]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# Trying_Conceive   No   Yes
# Negative
# 0                953  2376
# 1                 72    57
#
# Chi2 value= 42.71863221688029
# p-value= 6.320735989470612e-11
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# No change
# 0                139   124
# 1                886  2309
#
# Chi2 value= 72.3288442125074
# p-value= 1.8216524495704982e-17
# Degrees of freedom= 1
#
# Trying_Conceive   No   Yes
# Positive
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Previous_Children    No  Yes
# Age Direction
# Negative            216   68
# No change           879  397
# Positive           1268  673
# (14.773092370947904,
#  0.000619532011272414,
#  2,
#  array([[ 191.68580406,   92.31419594],
#         [ 861.23621822,  414.76378178],
#         [1310.07797772,  630.92202228]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          0         1
# 2         0          0         1
# 3         0          0         1
# 4         0          1         0
# Previous_Children    No   Yes
# Negative
# 0                  2147  1070
# 1                   216    68
#
# Chi2 value= 9.905417679220081
# p-value= 0.001647929236514932
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# No change
# 0                  1484  741
# 1                   879  397
#
# Chi2 value= 1.675180211785717
# p-value= 0.19556612197795692
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# Positive
# 0                  1095  465
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Previous_Children    No  Yes
# Height Direction
# Negative            717  333
# No change           342  209
# Positive           1304  596
# (8.812239660822828,
#  0.01220243410413441,
#  2,
#  array([[ 708.697515  ,  341.302485  ],
#         [ 371.89745787,  179.10254213],
#         [1282.40502714,  617.59497286]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          0         1
# 2         0          0         1
# 3         0          0         1
# 4         0          0         1
# Previous_Children    No  Yes
# Negative
# 0                  1646  805
# 1                   717  333
#
# Chi2 value= 0.37748841134419686
# p-value= 0.5389504705416757
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# No change
# 0                  2021  929
# 1                   342  209
#
# Chi2 value= 8.484305284793786
# p-value= 0.003582233463009745
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# Positive
# 0                  1059  542
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Previous_Children    No  Yes
# Weight Direction
# Negative           1345  467
# No change           190  144
# Positive            828  527
# (79.77104329828799,
#  4.7636302005438524e-18,
#  2,
#  array([[1223.00942588,  588.99057412],
#         [ 225.43330477,  108.56669523],
#         [ 914.55726935,  440.44273065]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          0         1
# 4         0          0         1
# Previous_Children    No  Yes
# Negative
# 0                  1018  671
# 1                  1345  467
#
# Chi2 value= 76.96046347561196
# p-value= 1.744148146591083e-18
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# No change
# 0                  2173  994
# 1                   190  144
#
# Chi2 value= 18.41005831129855
# p-value= 1.7811529766436736e-05
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# Positive
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Smoking Direction'],dfProfileLast_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Previous_Children    No  Yes
# Smoking Direction
# Negative            226  111
# No change          2079  974
# Positive             58   53
# (12.288129012690879,
#  0.002146182693382987,
#  2,
#  array([[ 227.45815481,  109.54184519],
#         [2060.6223936 ,  992.3776064 ],
#         [  74.91945159,   36.08054841]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         1          0         0
# 2         0          1         0
# 3         0          1         0
# 4         0          0         1
# Previous_Children    No   Yes
# Negative
# 0                  2137  1027
# 1                   226   111
#
# Chi2 value= 0.013739639687450584
# p-value= 0.9066887224204294
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# No change
# 0                   284  164
# 1                  2079  974
#
# Chi2 value= 3.728930363497451
# p-value= 0.05347762948521957
# Degrees of freedom= 1
#
# Previous_Children    No   Yes
# Positive
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Previous_Children     No   Yes
# Children Direction
# Negative              56     3
# No change           2285  1097
# Positive              22    38
# (46.21827288238353,
#  9.200884141208525e-11,
#  2,
#  array([[  39.82205084,   19.17794916],
#         [2282.6809483 , 1099.3190517 ],
#         [  40.49700086,   19.50299914]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Previous_Children    No   Yes
# Negative
# 0                  2307  1135
# 1                    56     3
#
# Chi2 value= 19.314611383463934
# p-value= 1.108547931934517e-05
# Degrees of freedom= 1
#
# Previous_Children    No   Yes
# No change
# 0                    78    41
# 1                  2285  1097
#
# Chi2 value= 0.13120182277993012
# p-value= 0.7171891880368275
# Degrees of freedom= 1
#
# Previous_Children    No   Yes
# Positive
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Previous_Children         No  Yes
# STI Positive Direction
# Negative                  74   21
# No change               1576  835
# Positive                  39    7
# (13.649650953513808,
#  0.0010864655384081156,
#  2,
#  array([[  62.8742163 ,   32.1257837 ],
#         [1595.68142633,  815.31857367],
#         [  30.44435737,   15.55564263]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          0         0
# 2         0          0         0
# 3         0          0         0
# 4         0          0         0
# Previous_Children    No   Yes
# Negative
# 0                  2289  1117
# 1                    74    21
#
# Chi2 value= 4.338948550520186
# p-value= 0.03724992063085946
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# No change
# 0                   787  303
# 1                  1576  835
#
# Chi2 value= 15.672949607816117
# p-value= 7.529334822308691e-05
# Degrees of freedom= 1
#
# Previous_Children    No   Yes
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Previous_Children           No  Yes
# Sex_Right_Time Direction
# Negative                   121   35
# No change                 1975  965
# Positive                   202  116
# (9.552176308263416,
#  0.008428907145257373,
#  2,
#  array([[ 105.00527241,   50.99472759],
#         [1978.94551845,  961.05448155],
#         [ 214.04920914,  103.95079086]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          0         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# Previous_Children    No   Yes
# Negative
# 0                  2242  1103
# 1                   121    35
#
# Chi2 value= 7.072651934769617
# p-value= 0.007826932344534701
# Degrees of freedom= 1
#
# Previous_Children    No  Yes
# No change
# 0                   388  173
# 1                  1975  965
#
# Chi2 value= 0.7583072442601692
# p-value= 0.38385878589505973
# Degrees of freedom= 1
#
# Previous_Children    No   Yes
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Previous_Children          No   Yes
# Contraception Direction
# Negative                   99    30
# No change                2161  1079
# Positive                   60    16
# (10.451801143975059,
#  0.0053755167396096985,
#  2,
#  array([[  86.87373004,   42.12626996],
#         [2181.94484761, 1058.05515239],
#         [  51.18142235,   24.81857765]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# Previous_Children    No   Yes
# Negative
# 0                  2264  1108
# 1                    99    30
#
# Chi2 value= 4.79397289947595
# p-value= 0.028559479849777573
# Degrees of freedom= 1
#
# Previous_Children    No   Yes
# No change
# 0                   202    59
# 1                  2161  1079
#
# Chi2 value= 12.115213751536444
# p-value= 0.0005001210494560276
# Degrees of freedom= 1
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Tested         No   Yes
# Height Direction
# Negative          366   700
# No change         182   372
# Positive          510  1403
# (21.86211321608767,
#  1.7893794019683906e-05,
#  2,
#  array([[ 319.2267195 ,  746.7732805 ],
#         [ 165.90206623,  388.09793377],
#         [ 572.87121427, 1340.12878573]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          0         1
# 2         0          0         1
# 3         0          0         1
# 4         0          0         1
# STI_Tested   No   Yes
# Negative
# 0           692  1775
# 1           366   700
#
# Chi2 value= 13.712109290821285
# p-value= 0.00021307619399269393
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# No change
# 0           876  2103
# 1           182   372
#
# Chi2 value= 2.4826981302763693
# p-value= 0.11510464186301432
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# Positive
# 0           548  1072
# 1           510  1403
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Tested         No   Yes
# Weight Direction
# Negative          616  1222
# No change         110   223
# Positive          332  1030
# (32.81390207140433,
#  7.491205318272554e-08,
#  2,
#  array([[ 550.41154826, 1287.58845174],
#         [  99.72091707,  233.27908293],
#         [ 407.86753467,  954.13246533]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          0         1
# 4         0          0         1
# STI_Tested   No   Yes
# Negative
# 0           442  1253
# 1           616  1222
#
# Chi2 value= 22.901435945829757
# p-value= 1.705244167056538e-06
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# No change
# 0           948  2252
# 1           110   223
#
# Chi2 value= 1.511374491089465
# p-value= 0.21892947097692506
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# Positive
# 0           726  1445
# 1           332  1030
#
# Chi2 value= 32.35204434024375
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Tested          No   Yes
# Alcohol Direction
# Negative           142   407
# No change          833  1844
# Positive            83   224
# (7.346939449714332,
#  0.0253882267839117,
#  2,
#  array([[ 164.40475517,  384.59524483],
#         [ 801.66034532, 1875.33965468],
#         [  91.93489952,  215.06510048]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# STI_Tested   No   Yes
# Negative
# 0           916  2068
# 1           142   407
#
# Chi2 value= 4.932597571297348
# p-value= 0.026354673428957878
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# No change
# 0           225   631
# 1           833  1844
#
# Chi2 value= 6.989834912171192
# p-value= 0.008197391419452141
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# Positive
# 0           975  2251
# 1            83   224
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Tested        No   Yes
# Month Direction
# Negative         101   291
# No change        889  2068
# Positive          68   116
# (7.5963299161480515,
#  0.022411860848920086,
#  2,
#  array([[ 117.38918766,  274.61081234],
#         [ 885.50976507, 2071.49023493],
#         [  55.10104727,  128.89895273]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# STI_Tested   No   Yes
# Negative
# 0           957  2184
# 1           101   291
#
# Chi2 value= 3.453181666648188
# p-value= 0.06313013670116549
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# No change
# 0           169   407
# 1           889  2068
#
# Chi2 value= 0.08841111208644035
# p-value= 0.7662068993487823
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# Positive
# 0           990  2359
# 1            68   116
#
# Chi2 value= 4.201526232834805
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Tested      No   Yes
# STI Direction
# Negative        68    47
# No change      976  1926
# Positive        14   502
# (247.90010576626085,
#  1.4763046961032145e-54,
#  2,
#  array([[  34.43815454,   80.56184546],
#         [ 869.03934333, 2032.96065667],
#         [ 154.52250212,  361.47749788]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# STI_Tested   No   Yes
# Negative
# 0           990  2428
# 1            68    47
#
# Chi2 value= 46.83325311167904
# p-value= 7.729075540152725e-12
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# No change
# 0            82   549
# 1           976  1926
#
# Chi2 value= 104.2369163855842
# p-value= 1.7951451253525508e-24
# Degrees of freedom= 1
#
# STI_Tested    No   Yes
# Positive
# 0           1044  1973
# 1             14   502
#
# Chi2 value= 212.1000141534971
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Tested                No   Yes
# Sex_Frequency Direction
# Negative                 180   441
# No change                729  1548
# Positive                 149   486
# (17.6388207630429,
#  0.00014783550108280526,
#  2,
#  array([[ 185.96603453,  435.03396547],
#         [ 681.87545995, 1595.12454005],
#         [ 190.15850552,  444.84149448]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# STI_Tested   No   Yes
# Negative
# 0           878  2034
# 1           180   441
#
# Chi2 value= 0.2782478469774265
# p-value= 0.597851946173692
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# No change
# 0           329   927
# 1           729  1548
#
# Chi2 value= 12.801076483683582
# p-value= 0.0003464199618359407
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# Positive
# 0           909  1989
# 1           149   486
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Tested                 No   Yes
# Sex_Right_Time Direction
# Negative                   49   110
# No change                 909  2056
# Positive                   65   254
# (14.675827016648018,
#  0.0006504061732401911,
#  2,
#  array([[  47.2428115 ,  111.7571885 ],
#         [ 880.97444089, 2084.02555911],
#         [  94.7827476 ,  224.2172524 ]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          0         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# STI_Tested    No   Yes
# Negative
# 0           1009  2365
# 1             49   110
#
# Chi2 value= 0.0246157392305837
# p-value= 0.8753283584768786
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# No change
# 0           149   419
# 1           909  2056
#
# Chi2 value= 4.241320412548876
# p-value= 0.039451472896847306
# Degrees of freedom= 1
#
# STI_Tested   No   Yes
# Positive
# 0           993  2221
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Positive     No  Yes
# STI Direction
# Negative         85    6
# No change      1866  123
# Positive        495    8
# (17.178744732988527,
#  0.0001860728365602395,
#  2,
#  array([[  86.17344173,    4.82655827],
#         [1883.50522648,  105.49477352],
#         [ 476.32133178,   26.67866822]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# STI_Positive    No  Yes
# Negative
# 0             2361  131
# 1               85    6
#
# Chi2 value= 0.10285059824558776
# p-value= 0.7484352561565122
# Degrees of freedom= 1
#
# STI_Positive    No  Yes
# No change
# 0              580   14
# 1             1866  123
#
# Chi2 value= 12.58750949930872
# p-value= 0.00038833326490808395
# Degrees of freedom= 1
#
# STI_Positive    No  Yes
# Positive
# 0             1951  129
# 1              495    8
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Positive Direction'],dfProfileLast_DiffLast['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Positive              No  Yes
# STI Positive Direction
# Negative                  94    1
# No change               2322  120
# Positive                  30   16
# (83.74539842857665,
#  6.530069279163155e-19,
#  2,
#  array([[  89.96128533,    5.03871467],
#         [2312.47851336,  129.52148664],
#         [  43.56020132,    2.43979868]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          0         0
# 2         0          0         0
# 3         0          0         0
# 4         0          0         0
# STI_Positive    No  Yes
# Negative
# 0             2352  136
# 1               94    1
#
# Chi2 value= 2.724666242112656
# p-value= 0.09880877446747535
# Degrees of freedom= 1
#
# STI_Positive    No  Yes
# No change
# 0              124   17
# 1             2322  120
#
# Chi2 value= 12.155914796315805
# p-value= 0.0004893243697354331
# Degrees of freedom= 1
#
# STI_Positive    No  Yes
# Positive
# 0             2416  121
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# STI_Positive                       No  Yes
# Menstrual_Information Direction
# Negative                           71    3
# No change                        2131  117
# Positive                           32    6
# (8.533630813774746,
#  0.014026380418050937,
#  2,
#  array([[7.00491525e+01, 3.95084746e+00],
#         [2.12797966e+03, 1.20020339e+02],
#         [3.59711864e+01, 2.02881356e+00]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# STI_Positive    No  Yes
# Negative
# 0             2375  134
# 1               71    3
#
# Chi2 value= 0.050006224132498514
# p-value= 0.823052443661276
# Degrees of freedom= 1
#
# STI_Positive    No  Yes
# No change
# 0              315   20
# 1             2131  117
#
# Chi2 value= 0.2048335801169704
# p-value= 0.6508472853497128
# Degrees of freedom= 1
#
# STI_Positive    No  Yes
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Age Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Menstrual_Information    No  Yes
# Age Direction
# Negative                183   41
# No change              1141  135
# Positive               1486  190
# (11.270952115671543,
#  0.0035689777888913573,
#  2,
#  array([[ 198.18639798,   25.81360202],
#         [1128.95465995,  147.04534005],
#         [1482.85894207,  193.14105793]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          0         1
# 2         0          0         1
# 3         0          0         1
# 4         0          1         0
# Menstrual_Information    No  Yes
# Negative
# 0                      2627  325
# 1                       183   41
#
# Chi2 value= 10.160621894268898
# p-value= 0.0014347221625681788
# Degrees of freedom= 1
#
# Menstrual_Information    No  Yes
# No change
# 0                      1669  231
# 1                      1141  135
#
# Chi2 value= 1.712628861204417
# p-value= 0.19064464415851892
# Degrees of freedom= 1
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Menstrual_Information              No  Yes
# Menstrual_Information Direction
# Negative                           92    5
# No change                        2692  340
# Positive                           26   21
# (54.823673715277444,
#  1.2450606683027014e-12,
#  2,
#  array([[  85.82178841,   11.17821159],
#         [2682.59445844,  349.40554156],
#         [  41.58375315,    5.41624685]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Menstrual_Information    No  Yes
# Negative
# 0                      2718  361
# 1                        92    5
#
# Chi2 value= 3.3627594046938762
# p-value= 0.06668623999721505
# Degrees of freedom= 1
#
# Menstrual_Information    No  Yes
# No change
# 0                       118   26
# 1                      2692  340
#
# Chi2 value= 5.658262044277895
# p-value= 0.01737333018076563
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Menstrual_Information      No  Yes
# Sex_Frequency Direction
# Negative                  480   80
# No change                1813  235
# Positive                  517   51
# (7.802600947910299,
#  0.020215604476638404,
#  2,
#  array([[ 495.46599496,   64.53400504],
#         [1811.98992443,  236.01007557],
#         [ 502.5440806 ,   65.4559194 ]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Menstrual_Information    No  Yes
# Negative
# 0                      2330  286
# 1                       480   80
#
# Chi2 value= 4.762549457383871
# p-value= 0.02908543604056465
# Degrees of freedom= 1
#
# Menstrual_Information    No  Yes
# No change
# 0                       997  131
# 1                      1813  235
#
# Chi2 value= 0.003508197749237543
# p-value= 0.9527688824316799
# Degrees of freedom= 1
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Menstrual_Information       No  Yes
# Sex_Right_Time Direction
# Negative                   122   20
# No change                 2350  316
# Positive                   275   20
# (7.7304236366277195,
#  0.020958482576406014,
#  2,
#  array([[ 125.70866903,   16.29133097],
#         [2360.13599742,  305.86400258],
#         [ 261.15533355,   33.84466645]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          0         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# Menstrual_Information    No  Yes
# Negative
# 0                      2688  346
# 1                       122   20
#
# Chi2 value= 0.7110626130359219
# p-value= 0.3990912756835818
# Degrees of freedom= 1
#
# Menstrual_Information    No  Yes
# No change
# 0                       460   50
# 1                      2350  316
#
# Chi2 value= 1.5676497522465245
# p-value= 0.21054865517249402
# Degrees of freedom= 1
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Height Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Sex_Right_Time     No  Unsure  Yes
# Height Direction
# Negative          193     402  461
# No change         110     210  227
# Positive          277     729  870
# (12.391308391316178,
#  0.014666681302972048,
#  4,
#  array([[176.05058925, 407.04110377, 472.90830698],
#         [ 91.19287151, 210.84420811, 244.96292038],
#         [312.75653924, 723.11468813, 840.12877264]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          0         1
# 2         0          0         1
# 3         0          0         1
# 4         0          0         1
# Sex_Right_Time   No  Unsure   Yes
# Negative
# 0               387     939  1097
# 1               193     402   461
#
# Chi2 value= 2.86319546819461
# p-value= 0.2389268755047199
# Degrees of freedom= 2
#
# Sex_Right_Time   No  Unsure   Yes
# No change
# 0               470    1131  1331
# 1               110     210   227
#
# Chi2 value= 6.169252952284891
# p-value= 0.0457471183494128
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Sex_Right_Time       No  Unsure   Yes
# Conceive Direction
# Negative             33      57    50
# No change           504    1223  1436
# Positive             18      23    22
# (14.859370386196836,
#  0.005001958389049389,
#  4,
#  array([[  23.08377897,   54.19489008,   62.72133096],
#         [ 521.5285205 , 1224.41740939, 1417.05407011],
#         [  10.38770053,   24.38770053,   28.22459893]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         1          0         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Sex_Right_Time   No  Unsure   Yes
# Negative
# 0               547    1284  1508
# 1                33      57    50
#
# Chi2 value= 7.022499304569667
# p-value= 0.02985957702374152
# Degrees of freedom= 2
#
# Sex_Right_Time   No  Unsure   Yes
# No change
# 0                76     118   122
# 1               504    1223  1436
#
# Chi2 value= 14.442752178136493
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Sex_Right_Time    No  Unsure   Yes
# Month Direction
# Negative          47     119   223
# No change        515    1155  1238
# Positive          18      67    97
# (39.16551172835401,
#  6.439033885223972e-08,
#  4,
#  array([[  64.85196896,  149.94222478,  174.20580627],
#         [ 484.80597873, 1120.90485772, 1302.28916355],
#         [  30.34205231,   70.15291751,   81.50503018]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Sex_Right_Time   No  Unsure   Yes
# Negative
# 0               533    1222  1335
# 1                47     119   223
#
# Chi2 value= 28.10946471094383
# p-value= 7.872402550809637e-07
# Degrees of freedom= 2
#
# Sex_Right_Time   No  Unsure   Yes
# No change
# 0                65     186   320
# 1               515    1155  1238
#
# Chi2 value= 37.113244843643315
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Children Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Sex_Right_Time       No  Unsure   Yes
# Children Direction
# Negative              7      15    35
# No change           550    1282  1465
# Positive              7      18    35
# (10.993084469631441,
#  0.026641845416138045,
#  4,
#  array([[   9.41652021,   21.95518453,   25.62829525],
#         [ 544.67135325, 1269.9340949 , 1482.39455185],
#         [   9.91212654,   23.11072056,   26.9771529 ]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Sex_Right_Time   No  Unsure   Yes
# Negative
# 0               573    1326  1523
# 1                 7      15    35
#
# Chi2 value= 6.493304700042219
# p-value= 0.038904227817026696
# Degrees of freedom= 2
#
# Sex_Right_Time   No  Unsure   Yes
# No change
# 0                30      59    93
# 1               550    1282  1465
#
# Chi2 value= 3.5857104286766344
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['STI Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Sex_Right_Time   No  Unsure   Yes
# STI Direction
# Negative         19      41    51
# No change       484    1113  1231
# Positive         70     174   260
# (11.596031353723903,
#  0.020622245246424642,
#  4,
#  array([[  18.47313389,   42.81382515,   49.71304095],
#         [ 470.64885274, 1090.78826605, 1266.56288121],
#         [  83.87801336,  194.3979088 ,  225.72407784]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Sex_Right_Time   No  Unsure   Yes
# Negative
# 0               561    1300  1507
# 1                19      41    51
#
# Chi2 value= 0.12526043170644666
# p-value= 0.9392907443040498
# Degrees of freedom= 2
#
# Sex_Right_Time   No  Unsure   Yes
# No change
# 0                96     228   327
# 1               484    1113  1231
#
# Chi2 value= 9.664692130659532
# p-value= 0.007967806327126528
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Frequency Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Sex_Right_Time            No  Unsure  Yes
# Sex_Frequency Direction
# Negative                  99     235  281
# No change                421     879  924
# Positive                  60     227  353
# (50.19673139620205,
#  3.284971339616895e-10,
#  4,
#  array([[102.52946249, 237.05518827, 275.41534924],
#         [370.77321069, 857.25323369, 995.97355562],
#         [106.69732682, 246.69157804, 286.61109514]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Sex_Right_Time   No  Unsure   Yes
# Negative
# 0               481    1106  1277
# 1                99     235   281
#
# Chi2 value= 0.306789313982863
# p-value= 0.8577911217369639
# Degrees of freedom= 2
#
# Sex_Right_Time   No  Unsure  Yes
# No change
# 0               159     462  634
# 1               421     879  924
#
# Chi2 value= 34.80878775305296
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Sex_Right_Time Direction'],dfProfileLast_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Sex_Right_Time             No  Unsure   Yes
# Sex_Right_Time Direction
# Negative                   56      56    47
# No change                 504    1200  1294
# Positive                   20      85   217
# (115.21091993038107,
#  5.626064262276905e-24,
#  4,
#  array([[  26.50761713,   61.28743892,   71.20494395],
#         [ 499.81029031, 1155.59586088, 1342.59384881],
#         [  53.68209256,  124.1167002 ,  144.20120724]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          0         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# Sex_Right_Time   No  Unsure   Yes
# Negative
# 0               524    1285  1511
# 1                56      56    47
#
# Chi2 value= 43.48484566048368
# p-value= 3.6089905229154664e-10
# Degrees of freedom= 2
#
# Sex_Right_Time   No  Unsure   Yes
# No change
# 0                76     141   264
# 1               504    1200  1294
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Weight Direction'],dfProfileLast_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Contraception       No  Yes
# Weight Direction
# Negative          1608  214
# No change          309   19
# Positive          1252  112
# (17.624317005684993,
#  0.000148911482930547,
#  2,
#  array([[1643.11838361,  178.88161639],
#         [ 295.7973819 ,   32.2026181 ],
#         [1230.08423449,  133.91576551]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          0         1
# 4         0          0         1
# Contraception    No  Yes
# Negative
# 0              1561  131
# 1              1608  214
#
# Chi2 value= 15.428680226878239
# p-value= 8.567804740517572e-05
# Degrees of freedom= 1
#
# Contraception    No  Yes
# No change
# 0              2860  326
# 1               309   19
#
# Chi2 value= 6.128170003642445
# p-value= 0.013304451238155606
# Degrees of freedom= 1
#
# Contraception    No  Yes
# Positive
# 0              1917  233
# 1              1252  112
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Alcohol Direction'],dfProfileLast_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Contraception        No  Yes
# Alcohol Direction
# Negative            473   69
# No change          2421  239
# Positive            275   37
# (8.7458809504392,
#  0.012614094548857218,
#  2,
#  array([[ 488.78713717,   53.21286283],
#         [2398.84462151,  261.15537849],
#         [ 281.36824132,   30.63175868]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Contraception    No  Yes
# Negative
# 0              2696  276
# 1               473   69
#
# Chi2 value= 5.75795372546272
# p-value= 0.01641417721642691
# Degrees of freedom= 1
#
# Contraception    No  Yes
# No change
# 0               748  106
# 1              2421  239
#
# Chi2 value= 8.193245857753128
# p-value= 0.004204662857230503
# Degrees of freedom= 1
#
# Contraception    No  Yes
# Positive
# 0              2894  308
# 1               275   37
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Conceive Direction'],dfProfileLast_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Contraception         No  Yes
# Conceive Direction
# Negative             110   31
# No change           2896  300
# Positive              53    9
# (25.24064119704498,
#  3.3041853720991994e-06,
#  2,
#  array([[ 126.89585172,   14.10414828],
#         [2876.30597234,  319.69402766],
#         [  55.79817593,    6.20182407]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         1          0         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Contraception    No  Yes
# Negative
# 0              3059  314
# 1               110   31
#
# Chi2 value= 23.153235912687556
# p-value= 1.4959125909808606e-06
# Degrees of freedom= 1
#
# Contraception    No  Yes
# No change
# 0               273   45
# 1              2896  300
#
# Chi2 value= 6.886076533204628
# p-value= 0.008686973277306389
# Degrees of freedom= 1
#
# Contraception    No  Yes
# Positive
# 0              3116  336
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Month Direction'],dfProfileLast_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Contraception      No  Yes
# Month Direction
# Negative          382    6
# No change        2607  337
# Positive          180    2
# (54.43359798274195,
#  1.513193206928809e-12,
#  2,
#  array([[ 349.90665908,   38.09334092],
#         [2654.96186682,  289.03813318],
#         [ 164.1314741 ,   17.8685259 ]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          1         0
# 3         0          1         0
# 4         0          1         0
# Contraception    No  Yes
# Negative
# 0              2787  339
# 1               382    6
#
# Chi2 value= 32.66136611513863
# p-value= 1.0969605978012744e-08
# Degrees of freedom= 1
#
# Contraception    No  Yes
# No change
# 0               562    8
# 1              2607  337
#
# Chi2 value= 53.277140656706976
# p-value= 2.896576879661165e-13
# Degrees of freedom= 1
#
# Contraception    No  Yes
# Positive
# 0              2989  343
# 1               180    2
#
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Menstrual_Information Direction'],dfProfileLast_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Contraception                      No  Yes
# Menstrual_Information Direction
# Negative                           76   17
# No change                        2706  287
# Positive                           43    4
# (7.778710859406649,
#  0.020458528748834477,
#  2,
#  array([[  83.85732525,    9.14267475],
#         [2698.76316629,  294.23683371],
#         [  42.37950846,    4.62049154]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          0         0
# 4         0          1         0
# Contraception    No  Yes
# Negative
# 0              3093  328
# 1                76   17
#
# Chi2 value= 6.774695391603415
# p-value= 0.00924592693754248
# Degrees of freedom= 1
#
# Contraception    No  Yes
# No change
# 0               463   58
# 1              2706  287
#
# Chi2 value= 1.0259238433834494
# p-value= 0.31111796614549986
# Degrees of freedom= 1
#
# Contraception    No  Yes
# ...

# %%
contigency = pd.crosstab(dfProfileLast_DiffLast['Contraception Direction'],dfProfileLast_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffLast['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
# Out:
# Contraception              No  Yes
# Contraception Direction
# Negative                  124    7
# No change                2993  314
# Positive                   52   24
# (43.99915742986391,
#  2.7906435016979584e-10,
#  2,
#  array([[ 118.1385885 ,   12.8614115 ],
#         [2982.32299374,  324.67700626],
#         [  68.53841776,    7.46158224]]))
#    Negative  No change  Positive
# 0         0          0         0
# 1         0          1         0
# 2         0          0         0
# 3         0          1         0
# 4         0          1         0
# Contraception    No  Yes
# Negative
# 0              3045  338
# 1               124    7
#
# Chi2 value= 2.5742393600003104
# p-value= 0.10861630052668932
# Degrees of freedom= 1
#
# Contraception    No  Yes
# No change
# 0               176   31
# 1              2993  314
#
# Chi2 value= 6.0048129022230405
# p-value= 0.014266906807011346
# Degrees of freedom= 1
#
# Contraception    No  Yes
# Positive
# ...

# %%
##dfProfileLast_DiffSecond
##GENDER

contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##Trying Conceive

contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##Previous children

contigency = pd.crosstab(dfProfileLast_DiffSecond['Age Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##STI_Tested
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Height Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Smoking Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##STI Positive
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Positive Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##Menstrual_Information
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

##Sex_Right_Time
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileLast_DiffSecond['Children Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileLast_DiffSecond['STI Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Frequency Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileLast_DiffSecond['Sex_Right_Time Direction'],dfProfileLast_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

##Contraception

contigency = pd.crosstab(dfProfileLast_DiffSecond['Weight Direction'],dfProfileLast_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Alcohol Direction'],dfProfileLast_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Conceive Direction'],dfProfileLast_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Month Direction'],dfProfileLast_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Menstrual_Information Direction'],dfProfileLast_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileLast_DiffSecond['Contraception Direction'],dfProfileLast_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileLast_DiffSecond['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileLast_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

# %%
##dfProfileFirst_DiffSecond
##GENDER

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
##Trying Conceive

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##Previous children

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##STI_Tested
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Smoking Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##STI Positive
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##Menstrual_Information

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['STI Positive Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

##Sex_Right_Time
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Children Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Frequency Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##Contraception
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Height Direction'],dfProfileFirst_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Conceive Direction'],dfProfileFirst_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffSecond['Contraception Direction'],dfProfileFirst_DiffSecond['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffSecond['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffSecond['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

# %%
##dfProfileFirst_DiffLast
##GENDER

contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Gender']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Gender'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
##Trying Conceive

contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Trying_Conceive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Trying_Conceive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")


##Previous children

contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Previous_Children']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Previous_Children'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##STI_Tested
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['STI_Tested']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Tested'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##STI Positive


contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['STI_Positive']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['STI_Positive'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##Menstrual_Information
contigency = pd.crosstab(dfProfileFirst_DiffLast['Age Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Age Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['STI Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['STI Positive Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['STI Positive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['Menstrual_Information']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Menstrual_Information'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

##Sex_Right_Time
contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffLast['Children Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Children Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Frequency Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Sex_Frequency Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##

contigency = pd.crosstab(dfProfileFirst_DiffLast['Sex_Right_Time Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Sex_Right_Time Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Sex_Right_Time']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Sex_Right_Time'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")

##Contraception

contigency = pd.crosstab(dfProfileFirst_DiffLast['Height Direction'],dfProfileFirst_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Height Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Weight Direction'],dfProfileFirst_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Weight Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Smoking Direction'],dfProfileFirst_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Smoking Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Alcohol Direction'],dfProfileFirst_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Alcohol Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Conceive Direction'],dfProfileFirst_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Conceive Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Month Direction'],dfProfileFirst_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Month Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Menstrual_Information Direction'],dfProfileFirst_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Menstrual_Information Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
contigency = pd.crosstab(dfProfileFirst_DiffLast['Contraception Direction'],dfProfileFirst_DiffLast['Contraception']) 
																			
contigency
stats.chi2_contingency(contigency)
dummies = pd.get_dummies(dfProfileFirst_DiffLast['Contraception Direction'])
dummies.head()
for series in dummies:
    nl = "\n"
    
    crosstab = pd.crosstab(dummies[f"{series}"], dfProfileFirst_DiffLast['Contraception'])
    print(crosstab, nl)
    chi2, p, dof, expected = stats.chi2_contingency(crosstab)
    print(f"Chi2 value= {chi2}{nl}p-value= {p}{nl}Degrees of freedom= {dof}{nl}")
##
# Out:
# Gender         Men  Women
# Age Direction
# Negative         6    316
# No change        6   1500
# Positive       344   1958
# (264.7605913871355,
#  3.220831963968855e-58,
#  2,
#  array([[  27.7559322 ,  294.2440678 ],
#         [ 129.81501211, 1376.18498789],
#         [ 198.42905569, 2103.57094431]]))
#    Negative  No change  Positive
# 0         0          1         0
# 1         0          0         1
# 2         0          0         1
# 3         0          0         1
# 4         0          1         0
# Gender    Men  Women
# Negative
# 0         350   3458
# 1           6    316
#
# Chi2 value= 19.319939503248158
# p-value= 1.1054589299521429e-05
# Degrees of freedom= 1
#
# Gender     Men  Women
# No change
# 0          350   2274
# 1            6   1500
#
# Chi2 value= 201.76292177633454
# p-value= 8.612537668178752e-46
# Degrees of freedom= 1
#
# Gender    Men  Women
# Positive
# 0          12   1816
# 1         344   1958
#
# Chi2 value= 262.22713286291315
# ...

# %%
dfProfileFirst_DiffSecond.Trying_Conceive
,dfProfileFirst_DiffSecond['Previous_Children']
                         ,dfProfileFirst_DiffSecond['STI_Tested'],
                         dfProfileFirst_DiffSecond['STI_Positive'],dfProfileFirst_DiffSecond['Menstrual_Information'],
                         dfProfileFirst_DiffSecond['Sex_Right_Time'],dfProfileFirst_DiffSecond['Contraception']
                         
                         dfProfileFirst_DiffSecond['Age Direction'],dfProfileFirst_DiffSecond['Height Direction'],
                         dfProfileFirst_DiffSecond['Weight Direction'],dfProfileFirst_DiffSecond['Smoking Direction'],
                         dfProfileFirst_DiffSecond['Alcohol Direction'],dfProfileFirst_DiffSecond['Conceive Direction'],
                         dfProfileFirst_DiffSecond['Month Direction'],dfProfileFirst_DiffSecond['Children Direction'],
                         dfProfileFirst_DiffSecond['STI Direction'],dfProfileFirst_DiffSecond['STI Positive Direction'],
                         dfProfileFirst_DiffSecond['Menstrual_Information Direction'],dfProfileFirst_DiffSecond['Sex_Frequency Direction'],
                         dfProfileFirst_DiffSecond['Sex_Right_Time Direction'],dfProfileFirst_DiffSecond['Contraception Direction']
# Out:
#   File "<ipython-input-72-929fca6ebd1c>", line 3
#     dfProfileFirst_DiffSecond("['STI_Tested'],")
#     ^
# IndentationError: unexpected indent
